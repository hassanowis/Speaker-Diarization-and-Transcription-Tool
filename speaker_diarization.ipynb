# %% [markdown]
# # **Install insanely-fast-whisper via pip**

# %%
# !pip install insanely-fast-whisper --ignore-requires-python
# Out:
# Collecting insanely-fast-whisper
#   Downloading insanely_fast_whisper-0.0.15-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from insanely-fast-whisper) (4.50.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (from insanely-fast-whisper) (1.5.2)
# Collecting pyannote-audio>=3.1.0 (from insanely-fast-whisper)
#   Downloading pyannote.audio-3.3.2-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: setuptools>=68.2.2 in /usr/local/lib/python3.11/dist-packages (from insanely-fast-whisper) (75.1.0)
# Requirement already satisfied: rich>=13.7.0 in /usr/local/lib/python3.11/dist-packages (from insanely-fast-whisper) (13.9.4)
# Collecting asteroid-filterbanks>=0.4 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (0.8.1)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (0.29.3)
# Collecting lightning>=2.0.1 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading lightning-2.5.1-py3-none-any.whl.metadata (39 kB)
# Collecting omegaconf<3.0,>=2.1 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pyannote.core>=5.0.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pyannote.core-5.0.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting pyannote.database>=5.0.1 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pyannote.database-5.1.3-py3-none-any.whl.metadata (1.1 kB)
# Collecting pyannote.metrics>=3.2 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyannote.pipeline>=3.0.1 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pyannote.pipeline-3.0.1-py3-none-any.whl.metadata (897 bytes)
# Collecting pytorch-metric-learning>=2.1.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pytorch_metric_learning-2.8.1-py3-none-any.whl.metadata (18 kB)
# Collecting semver>=3.0.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (0.13.1)
# Collecting speechbrain>=1.0.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading speechbrain-1.0.2-py3-none-any.whl.metadata (23 kB)
# Collecting tensorboardX>=2.6 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (2.6.0+cu124)
# Collecting torch-audiomentations>=0.11.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading torch_audiomentations-0.12.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: torchaudio>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from pyannote-audio>=3.1.0->insanely-fast-whisper) (2.6.0+cu124)
# Collecting torchmetrics>=0.11.0 (from pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading torchmetrics-1.7.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.0->insanely-fast-whisper) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.0->insanely-fast-whisper) (2.18.0)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate->insanely-fast-whisper) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (0.21.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers->insanely-fast-whisper) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from asteroid-filterbanks>=0.4->pyannote-audio>=3.1.0->insanely-fast-whisper) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.13.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading lightning_utilities-0.14.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pytorch-lightning (from lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading pytorch_lightning-2.5.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.0->insanely-fast-whisper) (0.1.2)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf<3.0,>=2.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.11/dist-packages (from pyannote.core>=5.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.11/dist-packages (from pyannote.core>=5.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.14.1)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.11/dist-packages (from pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.2.2)
# Requirement already satisfied: typer>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.15.2)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.11/dist-packages (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.6.1)
# Collecting docopt>=0.6.2 (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.11/dist-packages (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.10.0)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.11/dist-packages (from pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.13.1)
# Collecting optuna>=3.1 (from pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading optuna-4.2.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.17.1)
# Collecting hyperpyyaml (from speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.4.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.2.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorboardX>=2.6->pyannote-audio>=3.1.0->insanely-fast-whisper) (5.29.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.1->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.3.0)
# Collecting julius<0.3,>=0.2.3 (from torch-audiomentations>=0.11.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading julius-0.2.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting torch-pitch-shift>=1.2.2 (from torch-audiomentations>=0.11.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading torch_pitch_shift-1.2.5-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->insanely-fast-whisper) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->insanely-fast-whisper) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->insanely-fast-whisper) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers->insanely-fast-whisper) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.22)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.11.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.8.2)
# Collecting alembic>=1.5.0 (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting colorlog (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.0.39)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.19->pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.17.1->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.6.0)
# Collecting primePy>=1.3 (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading primePy-1.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.12.1->pyannote.database>=5.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.5.4)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.18.3)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.1.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->pyannote.metrics>=3.2->pyannote-audio>=3.1.0->insanely-fast-whisper) (1.17.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain>=1.0.0->pyannote-audio>=3.1.0->insanely-fast-whisper)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio>=3.1.0->insanely-fast-whisper) (3.1.1)
# Downloading insanely_fast_whisper-0.0.15-py3-none-any.whl (16 kB)
# Downloading pyannote.audio-3.3.2-py2.py3-none-any.whl (898 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 45.1 MB/s eta 0:00:00
# Downloading asteroid_filterbanks-0.4.0-py3-none-any.whl (29 kB)
# Downloading lightning-2.5.1-py3-none-any.whl (818 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.9/818.9 kB 43.3 MB/s eta 0:00:00
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.2 MB/s eta 0:00:00
# Downloading pyannote.core-5.0.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 4.9 MB/s eta 0:00:00
# Downloading pyannote.database-5.1.3-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 4.1 MB/s eta 0:00:00
# Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 4.1 MB/s eta 0:00:00
# Downloading pyannote.pipeline-3.0.1-py3-none-any.whl (31 kB)
# Downloading pytorch_metric_learning-2.8.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.9/125.9 kB 12.3 MB/s eta 0:00:00
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading speechbrain-1.0.2-py3-none-any.whl (824 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.8/824.8 kB 43.2 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 73.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.3 MB/s eta 0:00:00
# Downloading torch_audiomentations-0.12.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.2 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.0-py3-none-any.whl (960 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.9/960.9 kB 56.3 MB/s eta 0:00:00
# Downloading lightning_utilities-0.14.2-py3-none-any.whl (28 kB)
# Downloading optuna-4.2.1-py3-none-any.whl (383 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.6/383.6 kB 26.2 MB/s eta 0:00:00
# Downloading torch_pitch_shift-1.2.5-py3-none-any.whl (5.0 kB)
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading pytorch_lightning-2.5.1-py3-none-any.whl (822 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.0/823.0 kB 55.1 MB/s eta 0:00:00
# Downloading alembic-1.15.1-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 20.6 MB/s eta 0:00:00
# Downloading primePy-1.3-py3-none-any.whl (4.0 kB)
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 10.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 43.3 MB/s eta 0:00:00
# Building wheels for collected packages: antlr4-python3-runtime, docopt, julius
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144555 sha256=18634ea7acc200c2499c6cc30a97b18dad135f46d2b2ddf031a3a4030e74f403
#   Stored in directory: /root/.cache/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=189f64320377bb7c4bb1447627e5779a39612134cf0a5fb79b16053764852351
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for julius (setup.py) ... done
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21869 sha256=40fed632aaef2c66508cf99eba6762db4c7097b65ca94bb104cf26304e80ad1f
#   Stored in directory: /root/.cache/pip/wheels/16/15/d4/edd724cefe78050a6ba3344b8b0c6672db829a799dbb9f81ff
# Successfully built antlr4-python3-runtime docopt julius
# Installing collected packages: semver, ruamel.yaml.clib, primePy, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, docopt, colorlog, antlr4-python3-runtime, tensorboardX, ruamel.yaml, omegaconf, nvidia-cusparse-cu12, nvidia-cudnn-cu12, lightning-utilities, pyannote.core, nvidia-cusolver-cu12, hyperpyyaml, alembic, optuna, torchmetrics, pytorch-metric-learning, pyannote.database, julius, asteroid-filterbanks, torch-pitch-shift, speechbrain, pytorch-lightning, pyannote.pipeline, pyannote.metrics, torch-audiomentations, lightning, pyannote-audio, insanely-fast-whisper
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed alembic-1.15.1 antlr4-python3-runtime-4.9.3 asteroid-filterbanks-0.4.0 colorlog-6.9.0 docopt-0.6.2 hyperpyyaml-1.2.2 insanely-fast-whisper-0.0.15 julius-0.2.7 lightning-2.5.1 lightning-utilities-0.14.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 omegaconf-2.3.0 optuna-4.2.1 primePy-1.3 pyannote-audio-3.3.2 pyannote.core-5.0.0 pyannote.database-5.1.3 pyannote.metrics-3.2.1 pyannote.pipeline-3.0.1 pytorch-lightning-2.5.1 pytorch-metric-learning-2.8.1 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 semver-3.0.4 speechbrain-1.0.2 tensorboardX-2.6.2.2 torch-audiomentations-0.12.0 torch-pitch-shift-1.2.5 torchmetrics-1.7.0

# %% [markdown]
# # **Install Required Python Packages**

# %%
# !pip install noisereduce librosa soundfile numpy moviepy
# Out:
# Collecting noisereduce
#   Downloading noisereduce-3.0.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from noisereduce) (1.14.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from noisereduce) (3.10.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from noisereduce) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from noisereduce) (1.4.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lazy_loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.7)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)
# Downloading noisereduce-3.0.3-py3-none-any.whl (22 kB)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-3.0.3

# %% [markdown]
# # **Speaker Diarization ,Transcription & Reduce Noise**

# %%
import subprocess
import json
import librosa
import soundfile as sf
import noisereduce as nr
import numpy as np
import os
from moviepy.editor import AudioFileClip  # Import moviepy

def convert_mp4_to_wav(input_file, output_file="converted_audio.wav"):
    """
    Converts an MP4 file to WAV format using moviepy's AudioFileClip.
    """
    try:
        audio = AudioFileClip(input_file)
        audio.write_audiofile(output_file, codec="pcm_s16le")
        audio.close()
        print(f"Converted {input_file} to WAV: {output_file}")
        return output_file
    except Exception as e:
        print("Error converting MP4 to WAV:", e)
        return None

def reduce_noise(input_path, output_path="cleaned_audio.wav"):
    """
    Applies noise reduction to improve speech clarity.
    - Detects a silent portion as the noise sample.
    - Reduces noise more aggressively.
    - Applies band-pass filtering for better results.
    - Normalizes the audio for clearer speech.
    """
    try:
        # Load audio
        y, sr = librosa.load(input_path, sr=None)

        # 🔹 Step 1: Find a silent portion to use as noise (instead of first second)
        silent_indices = np.where(np.abs(y) < 0.01)[0]  # Find low-amplitude areas
        if len(silent_indices) > sr:  # If we have enough silent data
            noise_sample = y[silent_indices[:sr]]  # Use first second of detected silence
        else:
            noise_sample = y[:sr]  # Fallback: first second of the file

        # 🔹 Step 2: Reduce Noise (More aggressive)
        reduced_audio = nr.reduce_noise(y=y, sr=sr, y_noise=noise_sample, prop_decrease=0.95)

        # 🔹 Step 3: Apply Band-Pass Filtering (Remove Low & High Frequencies)
        def bandpass_filter(audio, sr, lowcut=100, highcut=8000):
            fft = np.fft.rfft(audio)
            frequencies = np.fft.rfftfreq(len(audio), 1/sr)
            fft[(frequencies < lowcut) | (frequencies > highcut)] = 0  # Zero out unwanted frequencies
            return np.fft.irfft(fft)

        reduced_audio = bandpass_filter(reduced_audio, sr)

        # 🔹 Step 4: Normalize Audio (Boost speech clarity)
        reduced_audio = reduced_audio / np.max(np.abs(reduced_audio)) * 0.9

        # Save cleaned audio
        sf.write(output_path, reduced_audio, sr)
        print(f"✅Noise reduction applied. Cleaned audio saved to: {output_path}")

        return output_path  # Return cleaned audio path

    except Exception as e:
        print(f"Error in noise reduction: {e}")
        return input_path  # If noise reduction fails, return original file

def transcribe_audio(input_path, diarization_model="pyannote/speaker-diarization-3.1", hf_token="HUGGINGFACE_TOKEN"):
    """
    Transcribes an audio file and returns speaker-diarized text with improved accuracy.
    """
    # 🔹 Step 0: Check if input is an MP4 and convert it to WAV if necessary
    filename, file_extension = os.path.splitext(input_path)
    if file_extension.lower() == ".mp4":
        converted_path = convert_mp4_to_wav(input_path)
        if converted_path is None:
            print("Conversion failed. Exiting transcription.")
            return None
        input_path = converted_path

    # Step 1: Apply Noise Reduction
    cleaned_audio_path = reduce_noise(input_path)

    # Step 2: Run transcription on the cleaned audio using the CLI tool
    command = [
        "insanely-fast-whisper",
        "--file-name", cleaned_audio_path,
        "--diarization_model", diarization_model,
        "--hf-token", hf_token,
    ]

    try:
        # Run the transcription command
        subprocess.run(command, text=True, capture_output=True, check=True)

        # Read the output JSON file
        with open("output.json", "r", encoding="utf-8") as file:
            data = json.load(file)

        if not isinstance(data, dict) or "speakers" not in data:
            raise ValueError("Invalid JSON format: expected a dictionary with 'speakers' key.")

        formatted_result = {"speakers": []}

        for segment in data["speakers"]:
            start_time, end_time = segment["timestamp"]

            # 🔹 Fix reversed timestamps
            if start_time > end_time:
                start_time, end_time = end_time, start_time  # Swap values

            # 🔹 Skip empty text segments
            text = segment.get("text", "").strip()
            if not text:
                continue

            # Append cleaned segment
            formatted_result["speakers"].append({
                "speaker": segment.get("speaker", "UNKNOWN"),
                "timestamp": [round(float(start_time), 2), round(float(end_time), 2)],
                "text": text
            })

        return formatted_result

    except subprocess.CalledProcessError as e:
        print("Error executing command:\n", e.stderr)
        return None
    except (FileNotFoundError, json.JSONDecodeError, ValueError) as e:
        print("Error reading JSON:", e)
        return None

# Example usage
result = transcribe_audio("/content/drive/MyDrive/conv.MP4")  # Works with both MP4 and WAV

if result:
    print(json.dumps(result, indent=4, ensure_ascii=False))
else:
    print("Transcription failed.")
# Out:
# ✅ Noise reduction applied. Cleaned audio saved to: cleaned_audio.wav
# {
#     "speakers": [
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 0.0,
#                 1.8
#             ],
#             "text": "صباح الخير"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 1.8,
#                 2.5
#             ],
#             "text": "لندن"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 2.5,
#                 2.6
#             ],
#             "text": "أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك أهلاً وصحبتك احنا شركة ليندون من ناحية سلسلة"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 2.6,
#                 3.58
#             ],
#             "text": "او قروب"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 3.58,
#                 85.16
#             ],
#             "text": "او امكانك تصغر على القرض الأول من 100 دينار لغاية 200 دينار مدة القرض تكون 7 أيام أو 14 يوم أو 30 يوم حسب طلب حضرتك والرسوم حسب المدة حالياً أستاذ سائر نعم في عنا عدة شروط أساسية لمنح القرض سيد سائر جنتيتك أردنية نعم أنا بدعم بخدمة الطبية الملكية أهلاً وسهلاً بحضرتك أهلاً أمر حضرتك ما بين الواحد وعشرين سنة لغاية الخمسة وعشرين سنة خمسة وثلاث؟ 36 سنة فالأمر كله يا رب والإنزامية وجود مصدر دخل فيه فائر؟ أنا عسكري بقولك، أنا بدك تشوف رأسك 100% جهة العمل حضرتك عسكري نعم الحمد لل لله ربنا. الحمد لله. حتى استاذ"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 83.5,
#                 85.16
#             ],
#             "text": "ثائر بما انك عسكري فيه لنا عدة وثائق مطلوبة بالفرع صراحة. احنا منطلب شهادة تعيين ثارية المصبول. موجودة. موجودة. برضو منطلب كشف راتب موقع مختوم. يا اما من المالية يا اما من المديرية اللي بتداوم فيها. نعم موجود. اللي يكون عمره يومين. وبرضو منطلب هاتفك"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 83.5,
#                 125.92
#             ],
#             "text": "الهاتف يكون موجود معاك بالفرع وفعلا لك حاليا أستاذ ثائر إحنا في عنا زي ما يقولوها عرض 100% إمكانك تقدم على سلسلة من غاية 100 دينار إلى 200 دينار بدون أي رسوم حسن"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 125.92,
#                 128.76
#             ],
#             "text": "بما أن حضرتك أول مرة"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 128.76,
#                 129.98
#             ],
#             "text": "بدك تخطي من المستحيل"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 129.98,
#                 131.1
#             ],
#             "text": "طيب طيب"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 131.1,
#                 133.94
#             ],
#             "text": "يعني حتى الآن اللي بدك أخذ 100 أو 200"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 133.94,
#                 136.62
#             ],
#             "text": "بتفحهم خلال شهر 200"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 136.62,
#                 137.96
#             ],
#             "text": "100%"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 137.96,
#                 141.32
#             ],
#             "text": "يا إما بتفحهم خلال شهر أستاذي"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 141.32,
#                 142.6
#             ],
#             "text": "يا إما"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 142.6,
#                 144.26
#             ],
#             "text": "إذا وصلنا لتاريخ الاستحقاة"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 144.26,
#                 146.14
#             ],
#             "text": "وما توفر كامل المبلغ معاك"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 146.14,
#                 148.52
#             ],
#             "text": "بإمكانك تدفع رسوم"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 148.52,
#                 149.96
#             ],
#             "text": "تأجيل وتأجيل"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 145.1,
#                 246.62
#             ],
#             "text": "ترجمة نانسوم تأجيل وتأجيل. طيب طيب خليها بيننا و بينك مثلا. يعني هسا بدي احكي يعني بالان ابن اشرح يعني متل ما بقولوها. هلأ لو مثلا اخذت انا ميتين دينار. انا انا بدي ميتين دينار يعني ما اضطري يعني لزوجتي طالب الجامعة نعم لو مثلا اللهم صلى الله عليه وسلم تفعت 50 50 50 هذا الاتفاق اللي راح يتبينه بينك مثلا هات تتفعى التليفون نعم تتفعى شهر 50 50 50 50 ناس على أربع شهور بلا فضل ناري سيد سائر هو بظبط إنك تدفع أجزاء ولكن شرط وحيد فيه فائدة تأجل أجل واتفع يعني ادفع 50 واتفع بدل سائر كم بطل إذا بدك تدفع 50 بطل تأجل 50 دينار كم تأجيل هناك؟ إذا أردت أن تدفع 50 دينار فتحتها 50 دينار نعم أدفع 50 دينار تأجيل 150 دينار لشهر تقريباً 27 دينار و 80 قرش إذا أردت أن تدفع أعلى 50 ديتيم دينار. مية بالمية. المرة الجاي دك تدفع كمان خمسين بيظل على حظرتك مية. اه. بدك تدفع خمسين وتأجل المية تأجيل المية راح يكون ثمانتعشر دينار وخمسة وخمسين قرش. يعني كل ما هذا بيقل لي كويس? اه طبعا كل ما يقل لي اه. ايول للتأجيل بس هو في شرط وحيد"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 246.62,
#                 249.66
#             ],
#             "text": "للتأجيل في المجانية"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 249.66,
#                 250.34
#             ],
#             "text": "أستاذ العلي"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 250.34,
#                 253.18
#             ],
#             "text": "إنه ما تتأخر ولا"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 253.18,
#                 255.76
#             ],
#             "text": "أي يوم عن تاريخ الاستحقاق"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 255.76,
#                 257.64
#             ],
#             "text": "لأنه إما لو لا سمح الله"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 257.64,
#                 259.74
#             ],
#             "text": "لو اتأخرت يوم واحد عن تاريخ"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 259.74,
#                 260.56
#             ],
#             "text": "الاستحقاق"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 260.56,
#                 264.22
#             ],
#             "text": "سينزل عليك كافة رسوم القرن"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 264.22,
#                 266.18
#             ],
#             "text": "أو كافة رسوم السلوك"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 266.18,
#                 267.02
#             ],
#             "text": "مرشد مرشد"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 267.02,
#                 269.7
#             ],
#             "text": "حتى لو أنك أجلت ثلاث مرات"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 366.0,
#                 368.0
#             ],
#             "text": "ترجمة نانسي قنقر سوف ينزل عليك كافة رسوم القرى أو كافة قيوم السنة 100% حتى لو أنك أجلت ثلاث مرات وبالمرة الرابعة لأستاذ العزيز أخرت وصل عليك الغضب 100% تمام تمام إذا تحب أستاذ العزيز حالياً منحني أقدم لك طزيز تكون أمورك تهلة وبطيطة وما تتأخر بالفرح بكون مميز لك وليكن ما تمنعين أستاذ يعني أنا سكان قلبدي يعني سنقول لكي أنا بدعم المديرة الطبية فالسكان قلبدي وليكن وليكن حاليا أستاذ سائر بعد إذنك تريد تزودني في بعض المعلومات مصدر أول شي أ استاذي على 200 دينار ان شاء الله اقدم لك ان شاء الله تعالى على 30 يوم باذن الله ان شاء الله اني احاول اتفهم 30 يوم ان شاء الله تعالى ممكن ان تزودني في رقمك الوطني بعد اذنك 988 988 1054 1054 920 920 اسم حضرتك الكامل بعد اسمك سائر محمد عبد المنان الجباري الجباري نعم أهلا وسهلا فيك سيد سائر أهلا بك رقم الهاتف هو نفس الرقم هذا نعم 097 097 0 2018 2018 35 35 بعد إذنك سيد تير ممكن نزول تاريخ ميلار حضرتك 27 27 28 العمر كله يارب"
#         },
#         {
#             "speaker": "SPEAKER_02",
#             "timestamp": [
#                 368.0,
#                 370.0
#             ],
#             "text": "طول العمر كله يارب"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 370.0,
#                 372.0
#             ],
#             "text": "شمال"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 372.0,
#                 376.0
#             ],
#             "text": "سيد ساير بس بعد إذنك حضرتك من وين سمعت عن شركة ليندرس"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 376.0,
#                 378.0
#             ],
#             "text": "والله انا بتعمل خدمة على الطبية"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 378.0,
#                 380.0
#             ],
#             "text": "نعم"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 380.0,
#                 486.32
#             ],
#             "text": "وطلبت منها الحوالي مصاري مبلغ 100 دينار و 100 دينار يعني صرا 100 دينار و 100 دينار فما عليك تنخفض ففي عنده واحد هم بالدوام قال لي والله نائرك لندو شركة لندو وشركة لندو بتعطيك وما بتأخذ عليك ففتحت على الموقع تباقم لدي اللي قلت خدنا حاول واتجعت لبناش على التليفون صارت وتججع أكثر إن شاءهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهل الى الموضوع وكيف تتجهبد احنا فيه اننا فرعين باربد. اهو. فرع اه مجمع عمان. مجمع عمان. بشارع الحصن. مجمع عمان. وليس احنا بمجمع عمان موجودين استاذ العزيز المدخل الشرقي. بجانب اه تابسم بروين ايو باتجاه دول الثقافة ايه 100% نعم صحيح حالياً استاذي احنا دوامنا ان شاء الله بكون من 8 صباحاً لغاية 8 مساء ممكن تشرفنا بأي وقت ان شاء الله وان شاء الله اذا امورك تمام بالفرع ب10 دقايق بتست بتستلم. خلص على باكث الاشياء. ان شاء الله. اي خدمة اي استفتاء. الله يطولك الله يطولك الله. الله يطولك الله. الله يطولك حبيبك. يعني اروح اليوم اليوم ان شاء الله امورك تمام ان شاء الله. مين بالمئة? اكيد استاذ. ان شاء الله. ان شاء الله. ان شاء الله. ان شاء الله على قير إن شاء الله"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 486.32,
#                 489.1
#             ],
#             "text": "حبيب الله يعزك"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 489.1,
#                 490.3
#             ],
#             "text": "طول عمرك وبركه"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 490.3,
#                 492.2
#             ],
#             "text": "شكرا شكرا"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 492.2,
#                 493.6
#             ],
#             "text": "شكرا لك"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 493.6,
#                 496.24
#             ],
#             "text": "حبيب الله يعزك"
#         },
#         {
#             "speaker": "SPEAKER_01",
#             "timestamp": [
#                 496.24,
#                 497.5
#             ],
#             "text": "على حبيبك"
#         },
#         {
#             "speaker": "SPEAKER_00",
#             "timestamp": [
#                 497.5,
#                 498.18
#             ],
#             "text": "على محفظك"
#         }
#     ]
# }
